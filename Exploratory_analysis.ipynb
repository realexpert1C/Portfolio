# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
# <br>Перед отправкой проекта обязательно перезапускай ядро через Kernel -> Restart & Run All и проверяй, чтобы все ячейки отработали без ошибок. 50 ячейка сейчас падает с ошибкой. Поправь, пожалуйста, чтобы я смог проверить твой проект
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Теперь всё работает) Перехожу к проверке!
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Введение
#
# В настоящем исследовании предстоит изучить, обработать представленные данные. Провести исследование и сделать выводы по поставленным вопросам.
#
# В загруженном датасете присуствуют следующие данные по квартирам, которые продавались в Санкт-Петербурге и Лениниградской области в 2014 - 2019 годах:
#
# Описание данных
# + `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# + `balcony` — число балконов
# + `ceiling_height` — высота потолков (м)
# + `cityCenters_nearest` — расстояние до центра города (м)
# + `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# + `first_day_exposition` — дата публикации
# + `floor — этаж`
# + `floors_total` — всего этажей в доме
# + `is_apartment` — апартаменты (булев тип)
# + `kitchen_area` — площадь кухни в квадратных метрах (м²)
# + `last_price` — цена на момент снятия с публикации
# + `living_area` — жилая площадь в квадратных метрах (м²)
# + `locality_name` — название населённого пункта
# + `open_plan` — свободная планировка (булев тип)
# + `parks_around3000` — число парков в радиусе 3 км
# + `parks_nearest` — расстояние до ближайшего парка (м)
# + `ponds_around3000` — число водоёмов в радиусе 3 км
# + `ponds_nearest` — расстояние до ближайшего водоёма (м)
# + `rooms — число` комнат
# + `studio` — квартира-студия (булев тип)
# + `total_area` — общая площадь квартиры в квадратных метрах (м²)
# + `total_images` — число фотографий квартиры в объявлении
#
#
# ## План исследования
#
# ### Шаг 1.  Открыть файл с данными и изучить общую информацию
# - вывести общую информацию
# - построить гистограммы по измеряемым данным
#
# ### Шаг 2  Предобработка данных
# - определить, где есть пропуски данных, устранить
# - определить, где есть дубликаты, принять меры по их удалению или исправлению
# - проверить аномальные значения, выполнить действия по исправлению
# - изучить типы данных в столбцах и изменить при необходимости для целей исследования
#
# ### Шаг 3 Рассчитать значения по заданию проекта и добавить в таблицу дополнительные столбцы
# - цена одного квадратного метра;
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «первый», «последний», «другой»);
# - расстояние до центра города в километрах (перевести из м в км и округлить до целых значений).
#
# ### Шаг 4 Провеcти исследовательский анализ данных
# ##### Часть 1 Исследование столбцов с данными. Предварительные выводы
#
# Изучить следующие параметры объектов:
#
# + общая площадь;
# + жилая площадь;
# + площадь кухни;
# + цена объекта;
# + количество комнат;
# + высота потолков;
# + этаж квартиры;
# + тип этажа квартиры («первый», «последний», «другой»);
# + общее количество этажей в доме;
# + расстояние до центра города в метрах;
# + расстояние до ближайшего аэропорта;
# + расстояние до ближайшего парка;
# + день и месяц публикации объявления.
#
# Построить отдельные гистограммы для каждого из этих параметров.
# Описать наблюдения по параметрам в ячейке с типом `markdown`.
#
# ##### Часть 2 Изучить, как быстро продавались квартиры (`days_exposition`).
#
# - построить гистограмму;
# - посчитайте среднее и медиану;
# - в ячейке типа `markdown` описать, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
#
# ##### Часть 3  Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#
# Изучить, зависит ли цена от:
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
#
# Постройть графики, которые покажут зависимость цены от указанных выше параметров.
#
# ##### Часть 4  Посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделить населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`.
#
# ##### Часть 5  Выделить квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислить среднюю цену каждого километра. Описать, как стоимость объектов зависит от расстояния до центра города.
#
# ### Шаг 5 Сделать общий вывод.
#
# - описать аномалии
# - замеченные зависимости

# %% [markdown]
# # Шаг 1  Откройте файл с данными и изучите общую информацию

# %% [markdown]
# Загружаем необходимые для работы бибилиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если после кода вызывающего график добавить ";", то мы избавимся от строчки над графиком)
#
# 	data.hist(figsize=(15, 20));
# </div>

# %%
display(data.head(10))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для вывода таблиц лучше использовать функцию display
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Здесь необходимо написать короткий вывод о проблемах с данными (пропуски, дубликаты, неверный тип данных, странные значения и т.д.)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Вывод: при первичном изучении видно, что в преставленном датасете есть пропуски (NaN) в данных. Явных дубликатов нет. Есть странно высокие значения по столбцам с площадями квартир, жилой площади и кухни. Также имеет смысл исправить типы данных: в столбцах, где данные содержат количество неделимых объектов этажей, парков, водоемов, дней экспозиции
# лучше использовать целые числа. Столбец, содержащий информацию апартаменты или жилое помещение, предпочтительнее булевый тип данных, столбец с датой публикации соответственно должен иметь тип данных datetime
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# # Шаг 2  Предобработка данных

# %% [markdown]
# ## Определите, в каких столбцах есть пропуски.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Ввиду того, что для объектов недвижимости первым по значимости параметром является место расположения, то оставлять в столбце `'locality_name'` пропуски не целесообразно. Можно заполнить их пустой строкой, но полагаю возможным строки, в которых не указан адрес, из исследования исключить. Их всего 49 из 23699, поэтому данное действие не окажет существенного влияния на результат исследования:

# %%
data = data.dropna(subset=['locality_name'])

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Аналогично из исследования можно исключить строки c пропусками в столбце `'floors_total'`. Можно попробовать заполнить их наиболее часто встречающимися значениями, опираясь на номер этажа из столбца `'floor'`. Однако, учитывая всего 86 пропусков из 23699 отуствие этих строк не повлияют на результат:

# %%
data = data.dropna(subset=['floors_total'])

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Теперь рассмотрим столбец с данными о высоте потолков. Посмотрим, как распределены значения в этом столбце по частоте:

# %%
data['ceiling_height'].hist(bins=50, range=(2, 5));

# %% [markdown]
# Видим, что большая часть значений находится в диапазоне от 2.2 м до 4 м. Среднее значение будет 2.77. Однако, выше мы видели, что четверть всех зданий это пятиэтажки, большая часть которых были построены в 50-70-е годы. Это типовые серии, в которых высота потолков была в диапазоне 2.5 - 2.65 м. Попробуем найти медианное значение высоты потолков

# %%
data['ceiling_height'].mean()
# Out:
# 2.7712830605621157

# %%
data['ceiling_height'].median()
# Out:
# 2.65

# %% [markdown]
# Заполняем пропуски значений высоты потолков медианным значением:

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен с таким решением, так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %% [markdown]
# Данные о жилой площади зависят от планировки и количества комнат. Поэтому логично найти медианное значение жилой площади в каждой группе квартир и заполнить им соответствующие пропуски. Такой же подход можно использовать и при заполнении пропусков значений площади кухни. При заполнении добавим проверку, чтобы сумма площади кухни и жилой площади не превышала общую площадь квартиры:

# %%
for r in data['rooms'].unique():
    data.loc[(data['rooms'] == r) & (data['living_area'].isna()), 'living_area'] =\
    data.groupby('rooms').median()['living_area'][r]

# %%
for r in data['rooms'].unique():
    data.loc[(data['rooms'] == r) & (data['kitchen_area'].isna()), 'kitchen_area'] =\
    data.groupby('rooms').median()['kitchen_area'][r]
data.loc[(data['rooms'] == 0) & (data['kitchen_area'].isna()),
          'kitchen_area'] = data.fillna(0)

# %%
def check_area(x):
    k = x.loc['kitchen_area']
    l = x.loc['living_area']
    t = x.loc['total_area']
    # print('start', k)
    if (k + l) > t:
        k = 0.8 * k
        l = 0.8 * l
        x.loc['kitchen_area'] = k
        x.loc['living_area'] = l
    # print('finish', k)
    return x

# %%
data = data.apply(check_area, axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Хороший способ)
# </div>

# %% [markdown]
# В столбце, который показывает, является ли объект аппартаментами, вероятно пропуски говорят о том, что это жилые квартиры. Исходя из этого, следует все отсуствющие значения заполнить `False`

# %%
data['is_apartment'] = data['is_apartment'].fillna(value=False)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# В столбце, где указано количество балконов, отсутствие значений с высокой долей вероятности означает их отсутсвие, поэтому заполним пропуски нулями - 0

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Причина пропусков данных в столбце с периодом экспозиции не известна. Можно предположить, что на момент подготовки дата сета эти объекты еще были в продаже и не были заполнены данные о завершении публикации, поэтому и период не появился. Возможно другая причина.
#
# В любом случае попробуем от них избавиться. Найдем максимальное значение даты (самую позднюю дату публикации), которое максимально близко к возможной дате выгрузки датасета. Затем найдем разницу между этой датой и датой первой публикации объявления с пропуском периода.

# %%
#data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format="%Y/%m/%d")
#end_data = data['first_day_exposition'].max()
#for i in range(len(data)):
#    data.loc[data['days_exposition'].isna(), 'days_exposition'] =\
#    (end_data - data.loc[data['days_exposition'].isna(), 'first_day_exposition']).dt.days

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Пропуски в столбце days_exposition можно вообще не запонлять. Если тут пропуск, то значит квартира не продана.
# </div>

# %% [markdown]
# Теперь посмотрим столбцы, которые связаны с картографическими данными: количество парков и водоемов, а также расстояния до парков, водоемов, центра города и аэропорта.

# %%
data[{'airports_nearest', 'cityCenters_nearest', 'ponds_nearest', 'parks_nearest'}].hist(bins=50);

# %%
data[{'airports_nearest', 'cityCenters_nearest', 'ponds_nearest', 'parks_nearest'}].head(10)
# Out:
#    ponds_nearest  cityCenters_nearest  parks_nearest  airports_nearest
# 0          755.0              16028.0          482.0           18863.0
# 1            NaN              18603.0            NaN           12817.0
# 2          574.0              13933.0           90.0           21741.0
# 3          234.0               6800.0           84.0           28098.0
# 4           48.0               8098.0          112.0           31856.0
# 5            NaN                  NaN            NaN               NaN
# 6            NaN              19143.0            NaN           52996.0
# 7            NaN              11634.0            NaN           23982.0
# 8            NaN                  NaN            NaN               NaN
# 9            NaN              15008.0            NaN           50898.0

# %% [markdown]
# Предварительный вывод по картографическим данным: можно заметить, что в части случаев данные о расстояниях отсуствуют по одному и тому же объекту в нескольких колонках. Возможно причина
# этого, отсутствие каких-либо настроек при автоматическом заполнении картографических данных, связанных с определением места расположения объекта.

# %% [markdown]
# Сгруппируем данные по названию локации и заполним пропуски медианным значением расстояния от объектов той же локации до центра, аэропорта, парка, водоема по соответствующей группе. Для корректного расчета медианных значаний заполним пропущенные значения "заглушками" - приблизительными значениями
#
# Но перед этим попробуем устранить неявные дубликаты в названиях, потому что один и тот же населенный пункт может быть указаны по разному.

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %%
def clean(name):
    splited_name = name.split(' ')
    words_for_remove = {'село', 'поселок', 'посёлок', 'городского', 'типа', 'городской', 'при',\
                        'железнодорожной', 'станции'}
    good_words = [word for word in splited_name if word.lower() not in words_for_remove]
    print(good_words)
    return ' '.join(good_words)

# %%
data['locality_name'] = data['locality_name'].apply(clean)
# Out:
# ['Санкт-Петербург']
# ['Шушары']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Янино-1']
# ['Парголово']
# ['Санкт-Петербург']
# ['Мурино']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Ломоносов']
# ['Сертолово']
# ['Петергоф']
# ['Пушкин']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Парголово']
# ['Санкт-Петербург']
# ['деревня', 'Кудрово']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Пушкин']
# ['Санкт-Петербург']
# ['Коммунар']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Колпино']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Красный', 'Бор']
# ['Мурино']
# ['Санкт-Петербург']
# ['Парголово']
# ['Санкт-Петербург']
# ['Петергоф']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Гатчина']
# ['Санкт-Петербург']
# ['Санкт-Петербург']
# ['Пушкин']
# ...

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Александровская', 'Алексеевка', 'Аннино', 'Барышево',
#        'Белоостров', 'Бокситогорск', 'Большая Ижора', 'Бугры', 'Будогощь',
#        'Важины', 'Вещево', 'Виллози', 'Вознесенье', 'Возрождение',
#        'Войсковицы', 'Войскорово', 'Володарское', 'Волосово', 'Волхов',
#        'Всеволожск', 'Выборг', 'Вырица', 'Высокоключевой', 'Высоцк',
#        'Гаврилово', 'Гарболово', 'Гатчина', 'Гладкое', 'Глажево',
#        'Глебычево', 'Гончарово', 'Громово', 'Дзержинского',
#        'Дружная Горка', 'Дружноселье', 'Дубровка', 'Елизаветино',
#        'Ефимовский', 'Жилгородок', 'Жилпосёлок', 'Житково', 'Заводской',
#        'Запорожское', 'Зеленогорск', 'Зимитицы', 'Ивангород', 'Ильичёво',
#        'Калитино', 'Каложицы', 'Каменногорск', 'Кикерино', 'Кингисепп',
#        'Кингисеппский', 'Кириши', 'Кировск', 'Кирпичное', 'Кобралово',
#        'Кобринское', 'Колпино', 'Коммунар', 'Коммунары', 'Кондратьево',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %%
#data['airports_nearest'] = data['airports_nearest'].fillna(25555)
#data['cityCenters_nearest'] = data['cityCenters_nearest'].fillna(15555)
#data['ponds_nearest'] = data['ponds_nearest'].fillna(0)
#data['parks_nearest'] = data['parks_nearest'].fillna(0)

# %%
#for area in data['locality_name'].unique():
#    data.loc[(data['locality_name'] == area) & (data['airports_nearest'] == 25555), 'airports_nearest'] =\
#    data.groupby('locality_name').median()['airports_nearest'][area]

# %%
#for area in data['locality_name'].unique():
#   data.loc[(data['locality_name'] == area) & (data['cityCenters_nearest'] == 15555), 'cityCenters_nearest'] =\
#   data.groupby('locality_name').median()['cityCenters_nearest'][area]

# %%
#for area in data['locality_name'].unique():
#    data.loc[(data['locality_name'] == area) & (data['ponds_nearest'] == 0), 'ponds_nearest'] =\
#    data.groupby('locality_name').median()['ponds_nearest'][area]

# %%
#for area in data['locality_name'].unique():
#    data.loc[(data['locality_name'] == area) & (data['parks_nearest'] == 0), 'parks_nearest'] =\
#    data.groupby('locality_name').median()['parks_nearest'][area]

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Пропуски в столбцах с картографическими данными лучше не трогать. Заполняя их таким образом, ты проставляешь одинаковые расстояния до центра (парка, прудов, аэропорта) для разных квартир, хотя они могут быть расположены в разных частях города. Эти пропуски заполнять не нужно
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %%
data['parks_around3000'].value_counts()
# Out:
# 0.0    10039
# 1.0     5647
# 2.0     1736
# 3.0      643
# Name: parks_around3000, dtype: int64

# %%
data['parks_around3000'].hist()
# Out:
# <AxesSubplot:>

# %%
data['ponds_around3000'].value_counts()
# Out:
# 0.0    9029
# 1.0    5662
# 2.0    1883
# 3.0    1491
# Name: ponds_around3000, dtype: int64

# %%
data['ponds_around3000'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# К количеству парков и водоемов этот же алгоритм не применить, потому что данные о парках и водоемах носят характер категорий: нет/1/2/3.
#
# Гистограммы столбцов `'parks_around3000'` и `'ponds_around3000'` показывают, что в радиусе 3000м от объектов парки распределены следующим образом: 3.5% объектов имеют в такой близости три парка, 9.5% имеют поблизости два парка, 31.8% один и 55.2% ни одного.
#
# Аналогичные результаты по водоемам: 8.2% - три водоема, 10.4% - два водоема, 31.1% - один водоем, 50.3% - ни одного.
#
# Можно предположить, что по объектам, где эти данные не заполнены, распределение будет похожим. Но определить, для какого конкретно объекта, какие значения (0, 1, 2 или 3) применить не представляется возможным.
#
# Поэтому по паркам и водоемам пока поставим "заглушки" в виде значения "-1"

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(value=-1)

# %%
data['ponds_around3000'] = data['ponds_around3000'].fillna(value=-1)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000            0
# parks_nearest           15535
# ponds_around3000            0
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Приведем в нормальный вид типы данных. Выше уже часть данных были преобразованы в нужные типы. Это необходимо для корректного проведения различных операций со столбцами, в том числе математических. Например, столбцы с данными, в которых есть целые числа и дробные числа, должны иметь соотвестующий тип данных `'int'` и `'float'`. Столбцы со значениями `True` и `False` должны иметь тип данных `'bool'`. Столбцы, в которых содержатся текстовые данные могут иметь тип `'object'`, а содержащие даты - `'datetime'`. Это позволит использовать соответствующие функции Python для работы с этими дынными целиком по столбцам. После приведения к нужным типам датасет будет готов к дальнейшей работе.

# %%
for i in ['floors_total', 'balcony', 'parks_around3000', 'ponds_around3000']:
    data[i] = data[i].astype(int)

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format="%Y/%m/%d")

# %%
#data['floors_total'] = data['floors_total'].astype(int)

# %%
#data['balcony'] = data['balcony'].astype(int)

# %%
#data['parks_around3000'] = data['parks_around3000'].astype(int)

# %%
#data['ponds_around3000'] = data['ponds_around3000'].astype(int)

# %%
#data['days_exposition'] = data['days_exposition'].astype(int)

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Методы fillna и astype можно применить к нескольким столбюца одновременно
#
# 	df.astype({ "col1": "float64", "col2": "int64"})
# <br>Если столбцов более двух, то можно применить цикл for для автоматизации процесса
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %%
data_copy = data.copy()

# %%
# data = data_copy.copy()

# %% [markdown]
# ## Удаление аномальных значений

# %% [markdown]
# Для поиска и аномальных значений в столбцах можно воспользоваться функцией, которая определит в каких столбцах есть значения, выбивающиеся за пределы нормального распределения значений в выборке

# %% [markdown]
# def search_out(column, coef=1.5, share_out_limit=0.1):
#     p25 = np.quantile(column, 0.25)
#     p75 = np.quantile(column, 0.75)
#
#     return (1 - (
#                 (column >= p25 - coef*(p75-p25)) &
#                 (column <= p75 + coef*(p75-p25))
#             ).mean()) > share_out_limit
#
# for column in data.columns:
#     print(f'В столбце {column} выбросов больше порога: {search_out(data[column], share_out_limit=0.05)}')

# %% [markdown]
# Видим, что значения выше заданного порога пристуствуют в следующих столбцах: 'last_price', 'total_area', 'ceiling_height'. Также из датасета следует проверить столбец 'floor_total', так как на его гистограмме присутствуют значение 60 этажей

# %%
data['floors_total'].unique()
# Out:
# array([16, 11,  5, 14, 12, 26, 24, 27,  9,  6, 17, 25,  3, 23, 19, 18,  4,
#        22,  8,  2, 10,  7, 13, 15, 20, 28, 36, 21, 35, 34, 60,  1, 29, 33,
#        52, 37])

# %% [markdown]
# Согласно ТОП-10 самых высоких зданий Санкт-Петербурге, здесь нет жилых зданий высотой более 37 этажей. В нашем случае это две квартиры, одна из которых находится в Кронштадте на 4-м этаже и видимо опечатка, не 60, а 6 этажей. Вторая на 18-м этаже, 52-х этажного здания. Здесь также возможна опечатка. Возможно имели ввиду 22 или 32 этажа. Вероятность, что 22 выше, оставим это значение.

# %%
data[data['floors_total'] > 37]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2253             12   3800000.0        45.5           2018-06-28      2
# 16731             9   3978000.0        40.0           2018-09-24      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2253             2.88            60         27.4      4         False  ...
# 16731            2.65            52         10.5     18         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 2253            7.4        0        Кронштадт           67763.0
# 16731          14.0        0  Санкт-Петербург           20728.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 2253              49488.0                 2          342.0                 3
# 16731             12978.0                 1          793.0                 0
#
#        ponds_nearest  days_exposition
# 2253           614.0            166.0
# ...

# %%
data.at[2253, 'floors_total'] = 6
data.at[16731, 'floors_total'] = 22

# %% [markdown]
# Проверям. Теперь порядок.

# %%
data[data['floors_total'] > 37]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Следуюшим посмотрим стобец с ценами `'last_price'`

# %%
data.boxplot('last_price');

# %% [markdown]
# Не информативно. Абсолютное большинство значений цен находятся в диапазоне до 20 млн. рублей

# %%
data[data['last_price'] >= 1.6e7].value_counts().sum()
# Out:
# 408

# %% [markdown]
# 16 милионов и выше - 1082 объекта, что составляет менее 5 процентов от общего их количества, поэтому ограничим исследование диапазоном цен от 0 до 16 млн.рублей.

# %%
ax = data.boxplot('last_price', figsize=(6, 6), showfliers=True)
ax.set_ylim(-3e6, 1.6e7)
# Out:
# (-3000000.0, 16000000.0)

# %%
data['last_price'].hist(figsize=(8, 6), range=(0, 1.6e7), bins=50);

# %% [markdown]
# Удалим строки, в которых цена объекта превышает 16 млн.рублей

# %%
data = data[data.last_price < 1.6e7]

# %% [markdown]
# Cтолбец `'total_area'`

# %%
data['total_area'].hist(figsize=(8, 4), range=(0, 200), bins=50);

# %%
ax = data.boxplot('total_area', figsize=(6, 6), showfliers=True)
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
data[data['total_area'] > 125].value_counts().sum()
# Out:
# 78

# %% [markdown]
# Согласно диаграммам большинство значений общей площади лежит в диапазоне до 125 квадратных метров. Проверим сколько точно значений более 125. 78 квартир от 22483 составляют 0.34%, исключаем.

# %%
data = data[data['total_area'] <= 125]

# %% [markdown]
# Столбец `'ceiling_height'`

# %%
data['ceiling_height'].hist(bins=50);

# %%
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,   2.65,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.61,   3.2 ,   3.25,
#          3.45,   2.77,   2.64,   2.57,   4.15,   4.  ,   2.47,   2.73,
#          2.84,   3.1 ,   2.34,   3.4 ,   2.72,   2.54,   2.51,   2.78,
#          2.76,  25.  ,   2.58,   3.7 ,   2.52,   3.5 ,   2.66,   2.59,
#          2.  ,   2.85,   3.3 ,   2.45,   2.92,   3.13,   3.8 ,   3.15,
#          3.55,   3.62,   3.12,   2.53,   2.46,   2.74,   5.  ,   2.79,
#          2.95,   4.06,   2.94,   3.54,   2.83,   2.4 ,   3.38,   3.01,
#          3.65,   2.71,   2.3 ,   2.48,   2.62,   3.57,   2.82,   3.98,
#          2.63,   3.83,   3.52,   2.88,   3.66,   4.19,   3.35,   4.8 ,
#          4.5 ,   4.2 ,   3.75,  32.  ,   3.68,   3.07,   3.37,   3.09,
#          8.  ,   3.16,   3.6 ,   3.34,   2.81,   3.44,   2.97,   4.37,
#          2.68,   3.9 ,   3.27,  27.  ,   4.1 ,   3.95,   2.93,   3.46,
# ...

# %% [markdown]
# Здесь, очевидно, следует оставить строки с высотой потолков от 2.5 до 5м. При этом в выборке с потолками выше 5 метров есть двузначные значения, которые являются опечатками и нужно перенести десятичную точку на один знак, отфильтровать значения ниже 2.5 метров, обновить основной датасет

# %%
height_more_five_change = data.query('ceiling_height > 5').copy()

# %%
height_more_five_change['ceiling_height'] = height_more_five_change['ceiling_height'] * 0.1

# %%
data.loc[data['ceiling_height'] > 5, 'ceiling_height'] = height_more_five_change['ceiling_height']

# %% [markdown]
# Отсекаем оставшиеся объекты с потолками 5 метров и выше

# %%
data = data[data['ceiling_height'] < 5]

# %% [markdown]
# Отсекаем оставшиеся объекты с потолками ниже 2.5 метра

# %%
data = data[data['ceiling_height'] >= 2.5]

# %% [markdown]
# Проверяем. Теперь порядок.

# %%
data['ceiling_height'].unique()
# Out:
# array([2.7 , 2.65, 3.03, 2.5 , 2.67, 2.56, 3.05, 2.75, 2.6 , 2.9 , 2.8 ,
#        2.55, 3.  , 2.61, 3.2 , 3.25, 3.45, 2.77, 2.64, 2.57, 4.15, 4.  ,
#        2.73, 2.84, 3.1 , 3.4 , 2.72, 2.54, 2.51, 2.78, 2.76, 2.58, 3.7 ,
#        2.52, 3.5 , 2.66, 2.59, 2.85, 3.3 , 2.92, 3.13, 3.8 , 3.15, 3.55,
#        3.62, 3.12, 2.53, 2.74, 2.79, 2.95, 4.06, 2.94, 3.54, 2.83, 3.38,
#        3.01, 3.65, 2.71, 2.62, 3.57, 2.82, 3.98, 2.63, 3.83, 3.52, 2.88,
#        3.66, 4.19, 3.35, 4.8 , 4.5 , 4.2 , 3.75, 3.68, 3.07, 3.37, 3.09,
#        3.16, 3.6 , 3.34, 2.81, 3.44, 2.97, 4.37, 2.68, 3.9 , 3.27, 4.1 ,
#        3.95, 2.93, 3.46, 3.47, 3.33, 3.63, 3.14, 3.32, 3.18, 2.98, 3.24,
#        3.36, 2.86, 3.08, 3.17, 3.11, 3.67, 3.28, 3.04, 3.26, 3.84, 3.23,
#        3.02, 2.96, 3.21, 2.87, 4.3 , 3.06, 3.39, 2.69, 3.22, 3.56, 3.85,
#        3.53, 3.93, 3.42, 2.99, 4.14, 3.78, 3.31, 3.88, 4.25, 4.7 , 2.89,
#        3.48, 3.49, 3.59, 2.91])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22123 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22123 non-null  int64
#  1   last_price            22123 non-null  float64
#  2   total_area            22123 non-null  float64
#  3   first_day_exposition  22123 non-null  datetime64[ns]
#  4   rooms                 22123 non-null  int64
#  5   ceiling_height        22123 non-null  float64
#  6   floors_total          22123 non-null  int64
#  7   living_area           22123 non-null  float64
#  8   floor                 22123 non-null  int64
#  9   is_apartment          22123 non-null  bool
#  10  studio                22123 non-null  bool
#  11  open_plan             22123 non-null  bool
#  12  kitchen_area          22123 non-null  float64
#  13  balcony               22123 non-null  int64
#  14  locality_name         22123 non-null  object
# ...

# %%
data_copy = data.copy()

# %%
# data = data_copy.copy()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Диапазоны для аномальных значений подобраны и удалены верно!
# </div>

# %% [markdown]
# # Шаг 3  Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# #### Цена одного квадратного метра `'price_per_meter'`

# %%
data['price_per_meter'] = data['last_price'] / data['total_area']
data['price_per_meter'] = data['price_per_meter'].round(1)

# %% [markdown]
# #### День недели публикации `'first_exp_weekday'`

# %%
data['first_exp_weekday'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# #### Месяц публикации объявления `'first_exp_month'`

# %%
data['first_exp_month'] = data['first_day_exposition'].dt.month

# %% [markdown]
# #### Год публикации объявления `'first_exp_year'`

# %%
data['first_exp_year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# #### Тип этажа квартиры (значения "первый", "последний", "другой") `'type_floor'`

# %%
change_a = (data['floor'] == 1)
change_b = (data['floor'] == data['floors_total'])
change_c = ((data['floor'] != data['floors_total']) & (data['floor'] != 1)) 

conditions = [change_a, change_b, change_c]
choices = ['первый', 'последний', 'другой']

data['type_floor'] = np.select(conditions, choices)

# %% [markdown]
# #### Расстояние до центра города в километрах `'cityCenters_nearest_km'`

# %%
data['cityCenters_nearest_km'] = data['cityCenters_nearest'] / 1000
data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].round()

# %%
data_copy = data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22123 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_images            22123 non-null  int64
#  1   last_price              22123 non-null  float64
#  2   total_area              22123 non-null  float64
#  3   first_day_exposition    22123 non-null  datetime64[ns]
#  4   rooms                   22123 non-null  int64
#  5   ceiling_height          22123 non-null  float64
#  6   floors_total            22123 non-null  int64
#  7   living_area             22123 non-null  float64
#  8   floor                   22123 non-null  int64
#  9   is_apartment            22123 non-null  bool
#  10  studio                  22123 non-null  bool
#  11  open_plan               22123 non-null  bool
#  12  kitchen_area            22123 non-null  float64
#  13  balcony                 22123 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# # Шаг 4  Проведите исследовательский анализ данных

# %% [markdown]
# ### Часть 1. Исследование столбцов с данными. Предварительные выводы

# %% [markdown]
# #### Общая площадь `'total_area'`

# %%
data['total_area'].hist(bins=100, figsize=(8, 6));

# %% [markdown]
# #### Вывод:
# Большую часть выборки составляют две группы: квартиры площадью примерно от 30 до 48 квадратных метров и от 50 до 65 квадратны метров. Видимо это одно- и двухкомнатные квартиры

# %%
data['total_area'].describe()
# Out:
# count    22123.000000
# mean        54.347032
# std         19.672582
# min         12.000000
# 25%         39.300000
# 50%         50.000000
# 75%         65.125000
# max        125.000000
# Name: total_area, dtype: float64

# %% [markdown]
# #### Жилая площадь `'living_area'`

# %%
data['living_area'].hist(bins=100, figsize=(8, 6));

# %% [markdown]
# #### Вывод:
# На диаграмме явно прослеживаются три пика. Это очевидно одно, двух и трехкомнатные квартиры. И наибольшее предложение в сегменте однокомнатных квартир с площадью комнаты 16-18 квадратных метров.

# %% [markdown]
# #### Площадь кухни  `'kitchen_area'`

# %%
data['kitchen_area'].hist(bins=100,  range=(0, 30), figsize=(8, 6));

# %% [markdown]
# #### Вывод:
# На диаграмме явно прослеживаются несколько групп квартир: с площадью кухни около 6 квадратных метров - это стандартные серии домов 60-х - 70-х годов прошлого века и большая часть ранее построенных зданий, в районе 8 квадратных метров - это улучшенные серии 80-х-начала 90-х годов и на третьем месте кухни площадью 10 квадратных метров и более - это уже здания с середины 90-х годов по настоящее время. Распределение вполне адекватно отражает особенности существующего жилого фонда. Нулевые значения площадей кухни - в студиях и возможно апартаментах.

# %% [markdown]
# #### Цена объекта  `'last_price'`

# %%
data['last_price'] = data['last_price'] / 1000000
data['last_price'].hist(bins=100, figsize=(8, 6));

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут можно разделить все значения в столбце last_price на 1 млн, чтобы они пришли в более понятный вид)
# </div>

# %%
data['last_price'].describe()
# Out:
# count    22123.000000
# mean         5.124434
# std          2.685726
# min          0.012190
# 25%          3.350000
# 50%          4.500000
# 75%          6.250000
# max         15.990000
# Name: last_price, dtype: float64

# %% [markdown]
# #### Вывод:
# Большинство предлагаемых к продаже объектов собственники оценивают в диапазоне от 3 до 6.5 млн. рублей, средняя цена предложения 5.12 млн. рублей.

# %% [markdown]
# #### Количество комнат  `'rooms'`

# %%
data['rooms'].hist(bins=15, figsize=(6, 4));

# %%
data.groupby('rooms')['rooms'].count()
# Out:
# rooms
# 0     191
# 1    7956
# 2    7720
# 3    5313
# 4     824
# 5     106
# 6      11
# 7       2
# Name: rooms, dtype: int64

# %% [markdown]
# #### Вывод:
# Продаваемые объекты имеют в основном одну или две комнаты, доля таких предложений на рынке 70%. Нулевые значения есть. Вполне возможно, они могли появиться при заполнении объявлений по студиям

# %% [markdown]
# #### Высота потолков  `'ceiling_height'`

# %%
data['ceiling_height'].hist(bins=50, figsize=(6, 4));

# %%
data['ceiling_height'].describe()
# Out:
# count    22123.000000
# mean         2.679434
# std          0.186751
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.800000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# #### Вывод:
# Распределение квартир по высоте потолков близко к распределению по площади кухни, так как это зависит от планировки и года постройки. Здесь также выделяется группа зданий серийной застроки 60-х - 70-х годов прошлого века со стандартными потолками 2.5м, а вот более старые здания попали в другой диапазон: здания до 60-х годов, как и здания после 70-х имеют более высокие потолки от 2.6 до 3 метров

# %% [markdown]
# #### Этаж квартиры  `'floor'`

# %%
data['floor'].hist(bins=30, figsize=(6, 4));

# %%
data.groupby('floor')['floor'].count()
# Out:
# floor
# 1     2810
# 2     3135
# 3     2839
# 4     2550
# 5     2429
# 6     1189
# 7     1127
# 8     1018
# 9     1007
# 10     651
# 11     492
# 12     492
# 13     365
# 14     318
# 15     326
# 16     303
# 17     214
# 18     167
# 19     127
# 20     103
# 21     113
# 22     109
# 23      96
# 24      60
# 25      43
# 26      24
# 27      10
# 28       1
# 29       1
# 30       1
# 31       1
# 32       1
# 33       1
# Name: floor, dtype: int64

# %% [markdown]
# #### Вывод:
# Распределение по этажам также повторяет наши наблюдения о составе жилого фонда. Очевидно, что большая часть предложений о продаже в пятиэтажных зданиях.

# %% [markdown]
# #### Тип этажа квартиры («первый», «последний», «другой»)  `'floor_type'`

# %%
data['type_floor'].hist(bins=30, figsize=(6, 4));

# %%
data.groupby('type_floor')['type_floor'].count()
# Out:
# type_floor
# другой       16262
# первый        2810
# последний     3051
# Name: type_floor, dtype: int64

# %% [markdown]
# #### Вывод:
# Если округлить до тысяч количество, то можно сказать, что на первых и последних этажах продется одинаковое количество квартир, а вместе они составляют 26 процентов от всего объема предложения

# %% [markdown]
# #### Общее количество этажей в доме `'floors_total'`

# %%
data['floors_total'].hist(bins=30, figsize=(6, 4));

# %% [markdown]
# #### Вывод:
# Диаграмма подтверждает выше сделанные наблюдения: самая большая группа предложений в пятиэтажных домах, второе место - девятиэтажные. Это в основной массе здания типовой жилой застройки 60-х - 80-х годов прошлого века

# %% [markdown]
# #### Расстояние до центра города в метрах `'cityCenters_nearest'`

# %%
data['cityCenters_nearest'].hist(bins=200, figsize=(8, 6));

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    16691.000000
# mean     14719.269846
# std       8528.451484
# min        208.000000
# 25%      10303.000000
# 50%      13427.000000
# 75%      16544.500000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %%
# data.query('cityCenters_nearest == 15555')['locality_name']

# %%
# проверка для СПб
data.query('locality_name == "Санкт-Петербург"')['cityCenters_nearest'].hist(bins=200, figsize=(8, 6));

# %% [markdown]
# #### Вывод:
# Большая часть объектов из выборки расположены на расстоянии от 10 до 17 километров от центра города. Выброс на значении 15555 метров обусловлен тем, что мной были установлена "заглушка" = 15555 при заполнении пропусков. И медиана по этим объектам не посчиталась, так как не были заполнены картографические данные. И кроме моей "заглушки" никаких расстояний по объектам в данных населенных пунктах нет. Я обратил внимание, что это происходит в основном с объектами из Ленинградской области. Возможно следует сообщить разработчикам об этой проблеме. И если пользователи не заполняют по каким-то причинам эти данные - подключить автоматическое заполнение геолокации. А если никаких данных, кроме названия нет, то ориентироваться, например по точке, где расположен главпочтамп соответствующего населенного пункта

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Закомментировал строки автозаполнения картографических данных. Общая картина практически не изменилась, большая часть объектов в выборке расположены примерно на расстоянии от 7 до 17 км от центра города
# </div>

# %% [markdown]
# #### Расстояние до ближайшего аэропорта `'airports_nearest'`

# %%
data['airports_nearest'].hist(bins=200, figsize=(8, 6));

# %% [markdown]
# Повторяется история с "заглушкой". Уберем ее и посмотрим

# %%
#data.query('locality_name == "Санкт-Петербург"')['airports_nearest'].hist(bins=200, figsize=(8, 6))

# %% [markdown]
# #### Вывод:
# Большая часть объектов из выборки расположены на расстоянии от 10 до 40 километров от аэропорта "Пулково"

# %% [markdown]
# #### Расстояние до ближайшего парка `'parks_nearest'`

# %%
data['parks_nearest'].hist(bins=200, figsize=(6, 4));

# %% [markdown]
# Посмотрим без "заглушки"

# %%
#data.query('parks_nearest > 0')['parks_nearest'].hist(bins=200, figsize=(8, 6))

# %% [markdown]
# #### Вывод:
# Подавляющее количество квартир расположено на расстоянии не более одного километра от ближайшего парка. Санкт-Петербург зеленый город.

# %% [markdown]
# #### Расстояние до ближайшего водоема `'ponds_nearest'`

# %%
data.query('ponds_nearest > 50')['ponds_nearest'].hist(bins=200, figsize=(8, 6));

# %% [markdown]
# #### Вывод:
# Аналогично паркам водоемы расположены на расстоянии не более одного километра от большинства квартир.

# %% [markdown]
# #### День недели публикации объявления `'first_exp_weekday'`

# %%
#data['first_exp_weekday'].hist(bins=20, figsize=(8, 6));
fig, ax = plt.subplots()
ax.hist(data['first_exp_weekday'], bins = 20, rwidth = 0.6)
ax.set_title('День недели первой публикации объявления, 0 - понедельник')
plt.show()

# %% [markdown]
# #### Вывод:
# Чаще объявления публиковались во вторник и четверг. Реже всего в воскресенье.

# %% [markdown]
# #### Месяц публикации объявления `'first_exp_month'`

# %%
# data['first_exp_month'].hist(bins=40, figsize=(8, 6));
fig, ax = plt.subplots()
ax.hist(data['first_exp_month'], bins = 30, rwidth = 0.5)
ax.set_title('Месяц первой публикации объявления')
plt.show()

# %% [markdown]
# #### Вывод:
# Самые активные по публикациям февраль, март, апрель и ноябрь. Самый "ленивый" для публикаций месяц  май, за ним январь. Видимо из-за длинных выходных.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для того чтобы подписать график мы можем использовать метод plt.title() и в конце кода применить plt.show(). По ссылкам ниже можно почитать подробнее как добавить название для графика или подписать его оси
#
#     https://pyprog.pro/mpl/mpl_title.html
#     https://pyprog.pro/mpl/mpl_axis_signatures.html
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Благодарю тебя за оценку и подсказку
# </div>

# %% [markdown]
# ### Часть 2. Изучите, как быстро продавались квартиры (`days_exposition`).

# %%
data['days_exposition'].hist(bins=40, figsize=(8, 6));

# %%
data['days_exposition'].describe()
# Out:
# count    19343.000000
# mean       175.210671
# std        213.909105
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        222.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### Вывод:
# Среднее значение по столбцу 177 дней. При этом половина всех квартира проданы за 90 дней и быстрее. Еще четверть квартир продавались от 90 до 225 дней. Быстрой можно считать продажу бысрее, чем за 42 дня. Слишком долгая экспозиция объекта - более 225 дней

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен! Если интересно, то можно посмотреть на диапазон от 0 до 100 дней. Там есть пики, которым можно найти очень логичное объяснение</div>
# </div>

# %%
data['days_exposition'][data['days_exposition'] < 100].hist(bins=50, figsize=(8, 6));

# %%
data['days_exposition'][data['days_exposition'] < 100].describe()
# Out:
# count    10105.000000
# mean        44.443840
# std         26.578914
# min          1.000000
# 25%         21.000000
# 50%         45.000000
# 75%         63.000000
# max         99.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Вижу пики на 45-м дне и на 60-м. Предполагаю, что это связано с автоматической настройкой платформы, где размещаются объявления. Видимо при определенных условиях, они автоматически снимаются с рекламы или пользователю предлагается принять решение, продлевать размещение или нет. Это нормально, что человек не стремится снять рекламу в момент, когда у него идет сделка. В это время у него другие заботы. А вот снять по напоминанию это возможно, и если он этого не сделал, то автоматически. Пока другого объяснения не вижу
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Верно! Это особенность функционирования системы размещения объявлений) Убедиться в этом можно по ссылке ниже
#
# 	https://yandex.ru/support/realty/owner/home/add-ads-housing.html
# </div>

# %% [markdown]
# ### Часть 3. Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %% [markdown]
# Изучим, зависит ли цена от:
#
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
#
# Постройм графики, которые покажут зависимость цены от указанных выше параметров

# %% [markdown]
# #### Зависимость между ценой и  общей площадью

# %%
last_price_from_total_area = data[['last_price', 'total_area']]

# %%
last_price_from_total_area.plot(x='last_price', y='total_area', kind='scatter', alpha=0.5, title='Зависимость между ценой и общей площадью', figsize=(8, 6), grid=True)
plt.show()

# %% [markdown]
# Посчитаем коэффициент корреляции между значениями общей площади и цены

# %%
data['last_price'].corr(data['total_area'])
# Out:
# 0.7377944281019331

# %% [markdown]
# Коэффициент положительный и его значение достаточно близко к единице - это значит есть сильная взаимосвязь между ценой и общей площадью. При увеличении одного показателя увеличивается и другой

# %% [markdown]
# #### Зависимость между ценой и  жилой площадью

# %%
data[['last_price', 'living_area']].plot(x='last_price', y='living_area', kind='scatter', alpha=0.5, title='Зависимость между ценой и жилой площадью', figsize=(8, 6), grid=True)
plt.show()

# %% [markdown]
# Посчитаем коэффициент корреляции между значениями жилой площади и цены

# %%
data['last_price'].corr(data['living_area'])
# Out:
# 0.5901427013607694

# %% [markdown]
# Коэффициент положительный и его значение 0.59 говорит нам о наличии взаимосвязи между ценой и общей площадью. При увеличении одного показателя увеличивается и другой. Однако, в данном случае эта зависимость ниже, чем между ценой и общей площадью.

# %% [markdown]
# #### Зависимость между ценой и площадью кухни

# %%
data[['last_price', 'kitchen_area']].plot(x='last_price', y='kitchen_area', kind='scatter', alpha=0.5, title='Зависимость между ценой и площадью кухни', figsize=(8, 6), grid=True)
plt.show()

# %% [markdown]
# Посчитаем коэффициент корреляции между значениями площади кухни и цены

# %%
data['last_price'].corr(data['kitchen_area'])
# Out:
# 0.5165544124363515

# %% [markdown]
# Картина та же, что и выше, но зависимость несколько меньше.

# %% [markdown]
# #### Зависимость между ценой и количеством комнат

# %%
data.groupby(['rooms'])['last_price'].agg('mean').round(2).plot(xlabel='количество комнат', ylabel='средняя цена', kind='bar')
plt.show()

# %%
data['last_price'].corr(data['rooms'])
# Out:
# 0.45695051695700567

# %% [markdown]
# Коэффициент корреляции положительный, чем больше комнат, тем выше цена

# %% [markdown]
# #### Зависимость между ценой и этажом, на котором расположена квартира (первый, последний, другой)

# %%
data.groupby(['type_floor'])['last_price'].agg('mean').round(2).plot(xlabel='тип этажа', ylabel='средняя цена', kind='bar' )
plt.show()

# %% [markdown]
# В среднем на первом этаже квартиры оцениваются дешевле, затем следуют последние этажи и лучше цены на квартиры, расположенные на других этажах

# %% [markdown]
# Чтобы посчитать корреляцию, приведем типы столбцов `'первый'`, `'последний'`, `'другой'` к числовым значениям: 1, 2, 3

# %%
change_a = (data['type_floor'] == 'первый')
change_b = (data['type_floor'] == 'последний')
change_c = (data['type_floor'] == 'другой') 

conditions = [change_a, change_b, change_c]
choices = [1, 2, 3]

data['type_floor_num'] = np.select(conditions, choices)

# %%
data['last_price'].corr(data['type_floor_num'])
# Out:
# 0.14683171380411777

# %% [markdown]
# Коэффициент корреляции положительный, но не значительно выше 0, взаимовязь есть, но невысокая

# %% [markdown]
# #### Зависимость между ценой и датой размещения объявления: годом, месяцем, днем

# %%
data.groupby(['first_exp_year'])['last_price'].agg('mean').round(2).plot(xlabel='год публикации', ylabel='средняя цена', kind='bar');
plt.show()

# %% [markdown]
# Неожиданный результат. Оказывается цена предложений снижалась несколько лет, а затем снова начался рост. Это отличается от общего мнения, что цены на недвижимость всегда растут

# %%
data.groupby(['first_exp_month'])['last_price'].agg('mean').round(2).plot(xlabel='месяц публикации', ylabel='средняя цена', kind='bar');

# %% [markdown]
# Самые высокие в среднем цены предложений в апреле и сентябре, самые низкие в июне

# %%
data.groupby(['first_exp_weekday'])['last_price'].agg('mean').round(2).plot(xlabel='день публикации', ylabel='средняя цена', kind='bar');

# %% [markdown]
# На неделе средняя цена предложения выше во вторник, самые низкие в субботу

# %% [markdown]
# ### Вывод:
# Самое большое влияние на цену квартир оказывают количество комнат, а также параметры площади: общей, жилой, кухни. Из объективных факторов следует отметить год публикации объявления. Очевидно, что рыночная ситуация меняется от года к году и влияет на цены квартир и платежеспособный спрос

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Зависимость цены изучена верно! Ещё тут можно использовать для визуализации pairplot из библиотеки seaborn
#
#     https://seaborn.pydata.org/generated/seaborn.pairplot.html
# </div>

# %% [markdown]
# ### Часть 4.
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые  пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`.

# %% [markdown]
# Найдем 10 населенных пунктов с наибольшим числом объявлений

# %%
data['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург    14325
# Мурино               586
# Шушары               438
# Всеволожск           394
# Пушкин               342
# Колпино              335
# Парголово            325
# Гатчина              304
# деревня Кудрово      299
# Выборг               230
# Name: locality_name, dtype: int64

# %%
top_ten_counts = ['Санкт-Петербург',
 'Мурино',
 'Шушары',
 'Всеволожск',
 'Пушкин',
 'Колпино',
 'Парголово',
 'Гатчина',
 'деревня Кудрово',
 'Выборг']

# %%
data_top_ten = data.loc[data['locality_name'].isin(top_ten_counts)]

# %%
data_top_ten['price_per_meter'].describe()
# Out:
# count     17578.000000
# mean     102825.859802
# std       26634.739748
# min         111.800000
# 25%       85493.200000
# 50%       99730.500000
# 75%      116411.150000
# max      387096.800000
# Name: price_per_meter, dtype: float64

# %%
data_top_ten[data_top_ten['price_per_meter'] == data_top_ten['price_per_meter'].max()]['locality_name']
# Out:
# 14741    Санкт-Петербург
# Name: locality_name, dtype: object

# %%
data_top_ten[data_top_ten['price_per_meter'] == data_top_ten['price_per_meter'].min()]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7     0.01219       109.0           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 8793            2.75            25         32.0     25         False  ...
#
#       ponds_around3000  ponds_nearest  days_exposition  price_per_meter  \
# 8793                 0            NaN              8.0            111.8
#
#      first_exp_weekday  first_exp_month  first_exp_year  type_floor  \
# 8793                 2                3            2019   последний
#
#       cityCenters_nearest_km  type_floor_num
# 8793                     9.0               2
#
# [1 rows x 29 columns]

# %% [markdown]
# Минимальное значение цены за квадратный метр выглядит в Санкт-Петербурге очень странно, похоже ошибка в данных. Попробуем удалить эту строку как аномальную методом drop и повторим поиск минимального значения

# %%
data_top_ten = data.loc[data['price_per_meter'] != 111.8]

# %%
data_top_ten[data_top_ten['price_per_meter'] == data_top_ten['price_per_meter'].min()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 14911             5        0.43        54.0           2018-06-26      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 14911            2.65             3         30.5      3         False  ...
#
#        ponds_around3000  ponds_nearest  days_exposition  price_per_meter  \
# 14911                -1            NaN             44.0           7963.0
#
#       first_exp_weekday  first_exp_month  first_exp_year  type_floor  \
# 14911                 1                6            2018   последний
#
#        cityCenters_nearest_km  type_floor_num
# 14911                     NaN               2
#
# [1 rows x 29 columns]

# %%
data_top_ten[data_top_ten['price_per_meter'] == data_top_ten['price_per_meter'].min()]['locality_name']
# Out:
# 14911    Свирь
# Name: locality_name, dtype: object

# %%
data_top_ten['price_per_meter'].describe()
# Out:
# count     22122.000000
# mean      93984.578998
# std       31402.705865
# min        7963.000000
# 25%       75555.600000
# 50%       93750.000000
# 75%      111470.600000
# max      387096.800000
# Name: price_per_meter, dtype: float64

# %% [markdown]
# #### Вывод:
# Самая высокая средняя цена недвижимости за квадратный метр среди 10-ти городов с максимальным количеством квартир в продаже 387096.80 рублей за квадратный метр в Санкт-Петербурге, самая низкая в Свири - 7963.00 рубля.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Всё верно! Как вариант, тут можно построить барплот для топ10, так будет более наглядно)
# </div>

# %% [markdown]
# ### Часть 5.
# #### Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %%
data_spb = data[data['locality_name'] == 'Санкт-Петербург'].copy()

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Незаполненные значения расстояния до центра в км не позволяют привести столбец 'cityCenters_nearest_km' к целочисленному типу. А я бы хотел это сделать, так как так будет удобнее оценивать цену на каждый километр. Ранее было замечено, что картографические данные отсутствуют в основном в объектах Ленинградской области. Поэтому посмотрим, как с этим делом в Санкт-Петербурге. Если количество пропусков менее 5% - удалим, а затем преобразуем тип данных в столбце 'cityCenters_nearest_km' в 'int'
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v2:</b>
# <br>Можно изменить тип данных без замены пропусков следующим образом
#
#     import numpy as np
#     df['col'] = np.floor(pd.to_numeric(df['col'], errors='coerce')).astype('Int64')
# </div>

# %%
data_spb.isna().sum()
# Out:
# total_images                 0
# last_price                   0
# total_area                   0
# first_day_exposition         0
# rooms                        0
# ceiling_height               0
# floors_total                 0
# living_area                  0
# floor                        0
# is_apartment                 0
# studio                       0
# open_plan                    0
# kitchen_area                 0
# balcony                      0
# locality_name                0
# airports_nearest            58
# cityCenters_nearest         42
# parks_around3000             0
# parks_nearest             7977
# ponds_around3000             0
# ponds_nearest             7303
# days_exposition           1704
# price_per_meter              0
# first_exp_weekday            0
# first_exp_month              0
# first_exp_year               0
# type_floor                   0
# cityCenters_nearest_km      42
# type_floor_num               0
# dtype: int64

# %%
data_spb = data.dropna(subset=['cityCenters_nearest_km'])

# %%
data_spb['cityCenters_nearest_km'] = data_spb['cityCenters_nearest_km'].astype(int)
# Out:
# /tmp/ipykernel_790/3667390613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_spb['cityCenters_nearest_km'] = data_spb['cityCenters_nearest_km'].astype(int)

# %%
data_spb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16691 entries, 0 to 23697
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_images            16691 non-null  int64
#  1   last_price              16691 non-null  float64
#  2   total_area              16691 non-null  float64
#  3   first_day_exposition    16691 non-null  datetime64[ns]
#  4   rooms                   16691 non-null  int64
#  5   ceiling_height          16691 non-null  float64
#  6   floors_total            16691 non-null  int64
#  7   living_area             16691 non-null  float64
#  8   floor                   16691 non-null  int64
#  9   is_apartment            16691 non-null  bool
#  10  studio                  16691 non-null  bool
#  11  open_plan               16691 non-null  bool
#  12  kitchen_area            16691 non-null  float64
#  13  balcony                 16691 non-null  int64
# ...

# %% [markdown]
# Ранее я округлил до целых и привел к типу `int` данные в столбце расстояние до центра в километрах, а затем сгруппировал данные об общей цене и цене за квадратный метр по группам, которыми являются километровые отрезки

# %%
pd.pivot_table(data_spb, index='cityCenters_nearest_km', values=('last_price', 'price_per_meter'), aggfunc=np.mean)
# Out:
#                         last_price  price_per_meter
# cityCenters_nearest_km
# 0                         9.248333    122387.691667
# 1                         9.414434    126260.103101
# 2                         8.865856    124978.428708
# 3                         7.952622    112853.517216
# 4                         8.452885    121630.402099
# ...                            ...              ...
# 61                        3.200000     60606.100000
# 62                        3.200000     69114.500000
# 63                        3.600000     62500.000000
# 65                        3.475000     71853.000000
# 66                        3.933333     73551.633333
#
# [61 rows x 2 columns]

# %%
data_spb[['cityCenters_nearest_km', 'last_price', 'price_per_meter']].corr()
# Out:
#                         cityCenters_nearest_km  last_price  price_per_meter
# cityCenters_nearest_km                1.000000   -0.354529        -0.404237
# last_price                           -0.354529    1.000000         0.537842
# price_per_meter                      -0.404237    0.537842         1.000000

# %%
#data_spb.query('cityCenters_nearest_km == 27')

# %% [markdown]
# Очевидно, что корелляция между расстоянием от центра Санкт-Петербурга и ценой отрицательная, то есть чем больше расстояние от центра города, тем выше цена. Однако на 27 километре присутствует необычно высокое значение. При ближайшем рассмотрении видим, что это двухкомнатная квартира за 14350000 рублей дает такое среднее значение, потому что на этом удалении от центра только два предложения. Сложно сказать, что это: ошибка или элитная квартира где-нибудь недалеко от Петродворца. Для этого требуется точный адрес.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Вывод по этому вопросу исследования не изменился, но исчезло необычно высокое значение средней цены на 27 километре от центра
# </div>

# %%
data_spb[['cityCenters_nearest_km', 'last_price']].plot(x='cityCenters_nearest_km', y='last_price', kind='scatter', alpha=0.5, title='Зависимость цены от расстояния от центра города', figsize=(8, 6), grid=True);
plt.show()

# %% [markdown]
# ## Шаг 5. Общий вывод

# %% [markdown]
# В процессе исследования были обнаружены и по возможности устранены аномалии в следующих столбцах: этажность зданий, высота потолков, площадь общая, кухни и жилая. Также отсечены слишком дорогие квартиры, стоимость которых могла влиять на результат, но так как это единичные случаи, то по ним невозожно отследить закономерности.
#
# В датасете было обнаружено большое количество картографических данных, при этом пропуски по нескольким столбцам в ощутимом по размерам объеме, особенно по Ленинградской области. Полагаю, это связано с какими-то техническими вопросами, потому что пользователи обычно совершают разные ошибки, а в этом случае прослеживается закономерность отсутствия данных возможно из-зи настроек автоматического заполнения расстояний по геопозиции. Принято решение эти пропуски не заполнять.
#
# Исследованы зависимости различных параметров друг от друга: цена от расстояния до центра, цена от площадей общей, жилой, кухни; цена от количества комнат. Также исследованы особенности рынка жилой недвижимости Санкт-Петербурга.
#
# Выводы, которые можно сделать:
#
# Большую часть предложения на рынке за исследованные годы составляли одно- и двухкомнатные квартиры общей площадью от 30 до 65 кв.м. с ценами в диапазоне от 3 до 6.5 млн.рублей.
# Очевидная зависимость наблюдается между размерами квартиры и ее стоимостью в сравнении с аналогами в той же локации.
# Также существует прямая зависимость удаленности квартиры от центра города. Расчетные величины показывают, что чем больше расстояние от центра города, тем меньше цена. Да, в общем понимании это действительно так. Однако, если мы внимательно посмотрим, то окажется, что на расстоянии 5-7 км есть значения средней цены за квадратный метр даже выше, чем в самом центре города. Этот факт можно объяснить следующим: цены на любом рынке определяются балансом спроса/предложения. В нашем случае основной товар на рынке жилой недвижимости - это квартиры для собственного проживания. И покупатели стремятся поселиться в районах, предназначенных для проживания (без промышленных и туристических объектов), насыщенных гражданской инфраструктурой (школами, детскими садами, учебными заведениями, медицинскими учреждениями). При этом, конечно важна близость к центру, потому что это: меньше пробок, экономия времени по пути работа-дом, и конечно, более высокая ликвидность приобретенной недвижимости. Этот факт подтвержадают данные о том, что основной объем предложения мы видим в "поясе" примерно от 5 до 15 километров от центра города. И в самом начале этого "пояса" (5-7 км от центра) цены не ниже, чем в самом центре. Также на цену влияют год постройки жилого дома и развитость инфраструктуры конкретного района.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>После всех внесённых правок, обязательно перепроверь общий вывод и промежуточные выводы и поправь их по необходимости
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Ты хорошо потрудился, большая часть работы сделана, но остаётся внести следующие правки:
# <br>- написать короткий вывод после первичного просмотра данных
# <br>- не заполнять пропуски в столбцах с картографическими данными
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Благодарю тебя за быструю и тщательную проверку моей работы, за полезные замечания и подсказки!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v2:</b>
# <br>А тебе спасибо за отличный проект)
# <br>Проделана огромная работа! У тебя подробные, понятные и логичные выводы, которые ты подкрепляешь фактами. Были использованы разные графики и способы, чтобы как можно более тщательно изучить данные и у тебя это получилось!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
